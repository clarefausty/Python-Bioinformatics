# %% [markdown]
# <a href="https://colab.research.google.com/github/clarefausty/Python-Bioinformatics/blob/main/Python_for_Bioinformatics_(Drug_Discovery_using_ML_%26_DA)_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data Collection Using CheMBL Database**
#
# **How to install Chembl web service package for easy retrieval of bioactivity**

# %%
pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.0.7)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.31.0)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2024.7.4)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (23.2.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-23.2.3-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.2.2)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (1.2.1)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.12.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.16.0)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-23.2.3 chembl_webresource_client-0.10.9 requests-cache-1.2.1 url-normalize-1.4.3

# %%
#import libraries
import pandas as pd
#Access and retrieve data from the ChEMBL database
#new_client is a specific module within this library that provides an interface for querying and retrieving data from the ChEMBL database
from chembl_webresource_client.new_client import new_client

# %%
#Search for target protein
#target search for cancer
target = new_client.target
#search for the key word cancer
target_query = target.search("cancer")
#Convert the result to a pandas DataFrame for easier manipulation and store in the value targets
targets = pd.DataFrame.from_dict(target_query[0:7])
targets
# Out:
#                                     cross_references                organism  \
# 0                                                 []            Homo sapiens
# 1                                                 []  Canis lupus familiaris
# 2                                                 []            Homo sapiens
# 3                                                 []            Homo sapiens
# 4                                                 []                    None
# 5  [{'xref_id': 'O14519', 'xref_name': None, 'xre...            Homo sapiens
# 6  [{'xref_id': 'P38398', 'xref_name': None, 'xre...            Homo sapiens
#
#                                         pref_name  score  species_group_flag  \
# 0        Cancer-related nucleoside-triphosphatase   13.0               False
# 1                 ABC-type xenobiotic transporter   13.0               False
# 2                         Cancer/testis antigen 1   13.0               False
# 3               Kita-kyushu lung cancer antigen 1   13.0               False
# 4                               Cancer cell lines   11.0               False
# 5  Cyclin-dependent kinase 2-associated protein 1   11.0               False
# 6     Breast cancer type 1 susceptibility protein   11.0               False
#
#   target_chembl_id                                  target_components  \
# 0    CHEMBL4295936  [{'accession': 'Q9BSD7', 'component_descriptio...
# 1    CHEMBL4739687  [{'accession': 'Q38JL0', 'component_descriptio...
# 2    CHEMBL4804257  [{'accession': 'P78358', 'component_descriptio...
# 3    CHEMBL5169155  [{'accession': 'Q5H943', 'component_descriptio...
# 4     CHEMBL614375                                                 []
# 5       CHEMBL5578  [{'accession': 'O14519', 'component_descriptio...
# 6       CHEMBL5990  [{'accession': 'P38398', 'component_descriptio...
#
#       target_type  tax_id
# 0  SINGLE PROTEIN  9606.0
# 1  SINGLE PROTEIN  9615.0
# 2  SINGLE PROTEIN  9606.0
# 3  SINGLE PROTEIN  9606.0
# 4       CELL-LINE     NaN
# 5  SINGLE PROTEIN  9606.0
# 6  SINGLE PROTEIN  9606.0

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Cancer-related nucleoside-triphosphatase* (7th entry)**

# %%
#assign the sixth entry(which correspond to the target protein: Cancer-related nucleoside-triphosphatase ) to the selected_target variable
selected_target = targets.target_chembl_id[6]
selected_target
# Out:
# 'CHEMBL5990'

# %% [markdown]
# ## **Here we will only retrieve only bioactivity data for that are reported as IC50 values in nM (nanomolar) unit**

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df[0:4]
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None      6222842                  []
# 1        None             None      6222843                  []
# 2        None             None      6222844                  []
# 3        None             None      6222845                  []
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 1   CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 2   CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 3   CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
# 3          B                    None                   None  BAO_0000190  ...
#
#   target_organism                             target_pref_name target_tax_id  \
# 0    Homo sapiens  Breast cancer type 1 susceptibility protein          9606
# 1    Homo sapiens  Breast cancer type 1 susceptibility protein          9606
# 2    Homo sapiens  Breast cancer type 1 susceptibility protein          9606
# 3    Homo sapiens  Breast cancer type 1 susceptibility protein          9606
#
#   text_value  toid  type units    uo_units upper_value  value
# 0       None  None  IC50    uM  UO_0000065        None    4.6
# 1       None  None  IC50    uM  UO_0000065        None  250.0
# 2       None  None  IC50    uM  UO_0000065        None   52.8
# 3       None  None  IC50    uM  UO_0000065        None  250.0
#
# [4 rows x 46 columns]

# %% [markdown]
# ## **Save the resulting bioactivity data to csv file bioactivity_data_csv**

# %%
df.to_csv("bioactivity_data.csv",index=False )

# %% [markdown]
# ## **Copy files to Google Drive**

# %%
##Mount the google drive into Colab so that it could be accessed to the Google drive with colab

import os
from google.colab import drive

# Create the directory if it does not exist
if not os.path.exists("/cancer/gdrive"):
    os.makedirs("/cancer/gdrive")

# Mount the Google Drive
drive.mount("/cancer/gdrive", force_remount=True)
# Out:
# Mounted at /cancer/gdrive

# %% [markdown]
# ## **Create a data folder in Colab Notebooks folder on Google Drive**

# %%
# !mkdir "/cancer/gdrive/MyDrive/Colab Notebooks/data"
# Out:
# mkdir: cannot create directory ‘/cancer/gdrive/MyDrive/Colab Notebooks/data’: File exists

# %%
# !cp bioactivity_data.csv "/cancer/gdrive/MyDrive/Colab Notebooks/data"

# %%
#to check the date folder was generated
# !ls -l "/cancer/gdrive/MyDrive/Colab Notebooks/data"
# Out:
# total 28
# -rw------- 1 root root 10974 Jul 14 09:56 bioactivity_data.csv
# -rw------- 1 root root 14676 Jun 30 16:29 bioactivity_data_csv
# -rw------- 1 root root  2435 Jul  7 15:45 bioactivity_preprocessed_data.csv

# %%
#to see the content of the csv file
! ls
# Out:
# bioactivity_data.csv  sample_data

# %%
#to take a glimpse of the bioactvty-data.csv file
! head bioactivity_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,,6222842,[],CHEMBL1785941,Inhibition of BRCA1 by fluorescence polarization assay,B,,,BAO_0000190,BAO_0000357,single protein format,CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O)N[C@H](C(=O)N[C@@H](Cc1ccccc1)C(N)=O)[C@@H](C)O,,,CHEMBL1781980,J Med Chem,2011,"{'bei': '9.34', 'le': '0.19', 'lle': '7.67', 'sei': '2.25'}",CHEMBL1784774,,CHEMBL1784774,5.34,0,http://www.openphacts.org/units/Nanomolar,1429759,=,1,1,=,,IC50,nM,,4600.0,CHEMBL5990,Homo sapiens,Breast cancer type 1 susceptibility protein,9606,,,IC50,uM,UO_0000065,,4.6
# ,,6222843,[],CHEMBL1785941,Inhibition of BRCA1 by fluorescence polarization assay,B,,,BAO_0000190,BAO_0000357,single protein format,CC(=O)N[C@@H](CCC(=O)O)C(=O)N1CCC[C@H]1C(=O)N[C@H](C(=O)N[C@@H](Cc1ccccc1)C(N)=O)[C@@H](C)O,Outside typical range,"Values for this activity type are unusually large/small, so may not be accurate",CHEMBL1781980,J Med Chem,2011,,CHEMBL1784771,,CHEMBL1784771,,0,http://www.openphacts.org/units/Nanomolar,1429756,>,1,1,>,,IC50,nM,,250000.0,CHEMBL5990,Homo sapiens,Breast cancer type 1 susceptibility protein,9606,,,IC50,uM,UO_0000065,,250.0
# ,,6222844,[],CHEMBL1785941,Inhibition of BRCA1 by fluorescence polarization assay,B,,,BAO_0000190,BAO_0000357,single protein format,CC(=O)N[C@@H](CC(C(=O)O)C(=O)O)C(=O)N1CCC[C@H]1C(=O)N[C@H](C(=O)N[C@@H](Cc1ccccc1)C(N)=O)[C@@H](C)O,,,CHEMBL1781980,J Med Chem,2011,"{'bei': '7.41', 'le': '0.14', 'lle': '6.54', 'sei': '1.74'}",CHEMBL1784772,,CHEMBL1784772,4.28,0,http://www.openphacts.org/units/Nanomolar,1429757,=,1,1,=,,IC50,nM,,52800.0,CHEMBL5990,Homo sapiens,Breast cancer type 1 susceptibility protein,9606,,,IC50,uM,UO_0000065,,52.8
# ,,6222845,[],CHEMBL1785941,Inhibition of BRCA1 by fluorescence polarization assay,B,,,BAO_0000190,BAO_0000357,single protein format,CC(=O)N[C@H](C(=O)N1CCC[C@H]1C(=O)N[C@H](C(=O)N[C@@H](Cc1ccccc1)C(N)=O)[C@@H](C)O)[C@@H](C)OP(=O)(O)O,Outside typical range,"Values for this activity type are unusually large/small, so may not be accurate",CHEMBL1781980,J Med Chem,2011,,CHEMBL1784773,,CHEMBL1784773,,0,http://www.openphacts.org/units/Nanomolar,1429758,>,1,1,>,,IC50,nM,,250000.0,CHEMBL5990,Homo sapiens,Breast cancer type 1 susceptibility protein,9606,,,IC50,uM,UO_0000065,,250.0
# ,,6222846,[],CHEMBL1785941,Inhibition of BRCA1 by fluorescence polarization assay,B,,,BAO_0000190,BAO_0000357,single protein format,CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N[C@@H](C)C(=O)N[C@H](C(=O)N[C@@H](Cc1ccccc1)C(N)=O)[C@@H](C)O,,,CHEMBL1781980,J Med Chem,2011,"{'bei': '8.84', 'le': '0.18', 'lle': '7.64', 'sei': '1.96'}",CHEMBL1784704,,CHEMBL1784704,4.82,0,http://www.openphacts.org/units/Nanomolar,1429673,=,1,1,=,,IC50,nM,,15000.0,CHEMBL5990,Homo sapiens,Breast cancer type 1 susceptibility protein,9606,,,IC50,uM,UO_0000065,,15.0
# ,,6222847,[],CHEMBL1785941,Inhibition of BRCA1 by fluorescence polarization assay,B,,,BAO_0000190,BAO_0000357,single protein format,CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O)N[C@@H](C)C(=O)N[C@@H](Cc1ccccc1)C(N)=O,,,CHEMBL1781980,J Med Chem,2011,"{'bei': '8.23', 'le': '0.16', 'lle': '6.15', 'sei': '2.05'}",CHEMBL1784770,,CHEMBL1784770,4.46,0,http://www.openphacts.org/units/Nanomolar,1429755,=,1,1,=,,IC50,nM,,35000.0,CHEMBL5990,Homo sapiens,Breast cancer type 1 susceptibility protein,9606,,,IC50,uM,UO_0000065,,35.0
# ,,6222848,[],CHEMBL1785941,Inhibition of BRCA1 by fluorescence polarization assay,B,,,BAO_0000190,BAO_0000357,single protein format,CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O)N[C@H](C(=O)N[C@@H](Cc1ccccc1)C(N)=O)C(C)C,,,CHEMBL1781980,J Med Chem,2011,"{'bei': '9.65', 'le': '0.19', 'lle': '6.54', 'sei': '2.53'}",CHEMBL1784703,,CHEMBL1784703,5.50,0,http://www.openphacts.org/units/Nanomolar,1429672,=,1,1,=,,IC50,nM,,3200.0,CHEMBL5990,Homo sapiens,Breast cancer type 1 susceptibility protein,9606,,,IC50,uM,UO_0000065,,3.2
# ,,6222849,[],CHEMBL1785941,Inhibition of BRCA1 by fluorescence polarization assay,B,,,BAO_0000190,BAO_0000357,single protein format,CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O)N[C@@H](CO)C(=O)N[C@@H](Cc1ccccc1)C(N)=O,,,CHEMBL1781980,J Med Chem,2011,"{'bei': '8.11', 'le': '0.16', 'lle': '7.24', 'sei': '1.90'}",CHEMBL1784775,,CHEMBL1784775,4.52,0,http://www.openphacts.org/units/Nanomolar,1429760,=,1,1,=,,IC50,nM,,30100.0,CHEMBL5990,Homo sapiens,Breast cancer type 1 susceptibility protein,9606,,,IC50,uM,UO_0000065,,30.1
# ,,6222850,[],CHEMBL1785941,Inhibition of BRCA1 by fluorescence polarization assay,B,,,BAO_0000190,BAO_0000357,single protein format,CC[C@H](C)[C@H](NC(=O)[C@@H]1CCCN1C(=O)[C@H](COP(=O)(O)O)NC(C)=O)C(=O)N[C@@H](Cc1ccccc1)C(N)=O,,,CHEMBL1781980,J Med Chem,2011,"{'bei': '8.82', 'le': '0.18', 'lle': '5.81', 'sei': '2.37'}",CHEMBL1784776,,CHEMBL1784776,5.15,0,http://www.openphacts.org/units/Nanomolar,1429761,=,1,1,=,,IC50,nM,,7100.0,CHEMBL5990,Homo sapiens,Breast cancer type 1 susceptibility protein,9606,,,IC50,uM,UO_0000065,,7.1

# %% [markdown]
# ## **Handling missng data**

# %%
#if any compound has missing value for the standard-value column and canonical_smiles then drop it
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]

df2
# Out:
#    action_type activity_comment  activity_id activity_properties  \
# 0         None             None      6222842                  []
# 1         None             None      6222843                  []
# 2         None             None      6222844                  []
# 3         None             None      6222845                  []
# 4         None             None      6222846                  []
# 5         None             None      6222847                  []
# 6         None             None      6222848                  []
# 7         None             None      6222849                  []
# 8         None             None      6222850                  []
# 9         None             None      6222851                  []
# 10        None             None      6222852                  []
# 11        None             None      6222853                  []
# 12        None             None      6222854                  []
# 13        None             None      6222855                  []
# 14        None             None      6222856                  []
# 15        None             None      6222857                  []
# 16        None             None      6222858                  []
# 17        None             None      6222859                  []
# 18        None             None      6222860                  []
#
#    assay_chembl_id                                  assay_description  \
# 0    CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 1    CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 2    CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 3    CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 4    CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 5    CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 6    CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 7    CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 8    CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 9    CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 10   CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 11   CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 12   CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 13   CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 14   CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 15   CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 16   CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 17   CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 18   CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
#
#    assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0           B                    None                   None  BAO_0000190
# 1           B                    None                   None  BAO_0000190
# 2           B                    None                   None  BAO_0000190
# 3           B                    None                   None  BAO_0000190
# 4           B                    None                   None  BAO_0000190
# 5           B                    None                   None  BAO_0000190
# 6           B                    None                   None  BAO_0000190
# 7           B                    None                   None  BAO_0000190
# 8           B                    None                   None  BAO_0000190
# 9           B                    None                   None  BAO_0000190
# 10          B                    None                   None  BAO_0000190
# 11          B                    None                   None  BAO_0000190
# 12          B                    None                   None  BAO_0000190
# 13          B                    None                   None  BAO_0000190
# 14          B                    None                   None  BAO_0000190
# 15          B                    None                   None  BAO_0000190
# 16          B                    None                   None  BAO_0000190
# 17          B                    None                   None  BAO_0000190
# 18          B                    None                   None  BAO_0000190
#
#     ... target_organism                             target_pref_name  \
# 0   ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 1   ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 2   ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 3   ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 4   ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 5   ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 6   ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 7   ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 8   ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 9   ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 10  ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 11  ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 12  ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 13  ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 14  ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 15  ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 16  ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 17  ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 18  ...    Homo sapiens  Breast cancer type 1 susceptibility protein
#
#    target_tax_id text_value  toid  type units    uo_units upper_value  value
# 0           9606       None  None  IC50    uM  UO_0000065        None    4.6
# 1           9606       None  None  IC50    uM  UO_0000065        None  250.0
# 2           9606       None  None  IC50    uM  UO_0000065        None   52.8
# 3           9606       None  None  IC50    uM  UO_0000065        None  250.0
# 4           9606       None  None  IC50    uM  UO_0000065        None   15.0
# 5           9606       None  None  IC50    uM  UO_0000065        None   35.0
# 6           9606       None  None  IC50    uM  UO_0000065        None    3.2
# 7           9606       None  None  IC50    uM  UO_0000065        None   30.1
# 8           9606       None  None  IC50    uM  UO_0000065        None    7.1
# 9           9606       None  None  IC50    uM  UO_0000065        None   18.4
# 10          9606       None  None  IC50    uM  UO_0000065        None   17.7
# 11          9606       None  None  IC50    uM  UO_0000065        None  171.7
# 12          9606       None  None  IC50    uM  UO_0000065        None   14.9
# 13          9606       None  None  IC50    uM  UO_0000065        None   98.4
# 14          9606       None  None  IC50    uM  UO_0000065        None  250.0
# 15          9606       None  None  IC50    uM  UO_0000065        None  250.0
# 16          9606       None  None  IC50    uM  UO_0000065        None   10.8
# 17          9606       None  None  IC50    uM  UO_0000065        None    1.0
# 18          9606       None  None  IC50    uM  UO_0000065        None    1.6
#
# [19 rows x 46 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 19

# %%
#operation to remove duplicate rows based on a specific column named 'canonical_smiles' and assgn t to the value "df2_nr"
df2_nr = df2.drop_duplicates(["canonical_smiles"])
df2_nr
# Out:
#    action_type activity_comment  activity_id activity_properties  \
# 0         None             None      6222842                  []
# 1         None             None      6222843                  []
# 2         None             None      6222844                  []
# 3         None             None      6222845                  []
# 4         None             None      6222846                  []
# 5         None             None      6222847                  []
# 6         None             None      6222848                  []
# 7         None             None      6222849                  []
# 8         None             None      6222850                  []
# 9         None             None      6222851                  []
# 10        None             None      6222852                  []
# 11        None             None      6222853                  []
# 12        None             None      6222854                  []
# 13        None             None      6222855                  []
# 14        None             None      6222856                  []
# 15        None             None      6222857                  []
# 16        None             None      6222858                  []
# 17        None             None      6222859                  []
# 18        None             None      6222860                  []
#
#    assay_chembl_id                                  assay_description  \
# 0    CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 1    CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 2    CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 3    CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 4    CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 5    CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 6    CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 7    CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 8    CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 9    CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 10   CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 11   CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 12   CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 13   CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 14   CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 15   CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 16   CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 17   CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
# 18   CHEMBL1785941  Inhibition of BRCA1 by fluorescence polarizati...
#
#    assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0           B                    None                   None  BAO_0000190
# 1           B                    None                   None  BAO_0000190
# 2           B                    None                   None  BAO_0000190
# 3           B                    None                   None  BAO_0000190
# 4           B                    None                   None  BAO_0000190
# 5           B                    None                   None  BAO_0000190
# 6           B                    None                   None  BAO_0000190
# 7           B                    None                   None  BAO_0000190
# 8           B                    None                   None  BAO_0000190
# 9           B                    None                   None  BAO_0000190
# 10          B                    None                   None  BAO_0000190
# 11          B                    None                   None  BAO_0000190
# 12          B                    None                   None  BAO_0000190
# 13          B                    None                   None  BAO_0000190
# 14          B                    None                   None  BAO_0000190
# 15          B                    None                   None  BAO_0000190
# 16          B                    None                   None  BAO_0000190
# 17          B                    None                   None  BAO_0000190
# 18          B                    None                   None  BAO_0000190
#
#     ... target_organism                             target_pref_name  \
# 0   ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 1   ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 2   ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 3   ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 4   ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 5   ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 6   ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 7   ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 8   ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 9   ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 10  ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 11  ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 12  ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 13  ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 14  ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 15  ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 16  ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 17  ...    Homo sapiens  Breast cancer type 1 susceptibility protein
# 18  ...    Homo sapiens  Breast cancer type 1 susceptibility protein
#
#    target_tax_id text_value  toid  type units    uo_units upper_value  value
# 0           9606       None  None  IC50    uM  UO_0000065        None    4.6
# 1           9606       None  None  IC50    uM  UO_0000065        None  250.0
# 2           9606       None  None  IC50    uM  UO_0000065        None   52.8
# 3           9606       None  None  IC50    uM  UO_0000065        None  250.0
# 4           9606       None  None  IC50    uM  UO_0000065        None   15.0
# 5           9606       None  None  IC50    uM  UO_0000065        None   35.0
# 6           9606       None  None  IC50    uM  UO_0000065        None    3.2
# 7           9606       None  None  IC50    uM  UO_0000065        None   30.1
# 8           9606       None  None  IC50    uM  UO_0000065        None    7.1
# 9           9606       None  None  IC50    uM  UO_0000065        None   18.4
# 10          9606       None  None  IC50    uM  UO_0000065        None   17.7
# 11          9606       None  None  IC50    uM  UO_0000065        None  171.7
# 12          9606       None  None  IC50    uM  UO_0000065        None   14.9
# 13          9606       None  None  IC50    uM  UO_0000065        None   98.4
# 14          9606       None  None  IC50    uM  UO_0000065        None  250.0
# 15          9606       None  None  IC50    uM  UO_0000065        None  250.0
# 16          9606       None  None  IC50    uM  UO_0000065        None   10.8
# 17          9606       None  None  IC50    uM  UO_0000065        None    1.0
# 18          9606       None  None  IC50    uM  UO_0000065        None    1.6
#
# [19 rows x 46 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
#declare the variable
selection = ["molecule_chembl_id", "canonical_smiles","standard_value"]
df3 = df2_nr[selection]
df3
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL1784774  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 1       CHEMBL1784771  CC(=O)N[C@@H](CCC(=O)O)C(=O)N1CCC[C@H]1C(=O)N[...
# 2       CHEMBL1784772  CC(=O)N[C@@H](CC(C(=O)O)C(=O)O)C(=O)N1CCC[C@H]...
# 3       CHEMBL1784773  CC(=O)N[C@H](C(=O)N1CCC[C@H]1C(=O)N[C@H](C(=O)...
# 4       CHEMBL1784704  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N[C@@H](C)C(=O)...
# 5       CHEMBL1784770  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 6       CHEMBL1784703  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 7       CHEMBL1784775  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 8       CHEMBL1784776  CC[C@H](C)[C@H](NC(=O)[C@@H]1CCCN1C(=O)[C@H](C...
# 9       CHEMBL1784777  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 10      CHEMBL2369531  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 11      CHEMBL2369532  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 12      CHEMBL1784779  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 13      CHEMBL1784780  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N[C@@H](C)C(=O)...
# 14      CHEMBL1784781  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 15      CHEMBL1784782  CC(=O)N[C@H](Cc1ccccc1)C(=O)N[C@@H](C(=O)N[C@H...
# 16      CHEMBL1784783  C[C@@H](O)[C@H](NC(=O)[C@@H]1CCCN1C(=O)[C@@H](...
# 17      CHEMBL1784784  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 18      CHEMBL1784785  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
#
#    standard_value
# 0          4600.0
# 1        250000.0
# 2         52800.0
# 3        250000.0
# 4         15000.0
# 5         35000.0
# 6          3200.0
# 7         30100.0
# 8          7100.0
# 9         18400.0
# 10        17700.0
# 11       171700.0
# 12        14900.0
# 13        98400.0
# 14       250000.0
# 15       250000.0
# 16        10800.0
# 17         1000.0
# 18         1600.0

# %%
#Saves dataframe to CSV file
df3.to_csv("bioactivity_data.csv",index=False )

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
# To read data from a CSV file into a Pandas DataFrame.
df4 = pd.read_csv("bioactivity_data.csv")
bioactivity_class = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %%
#Concatenating df4 with a bioactivity class Series to create df5.

df5 = pd.concat([df4, pd.Series(bioactivity_class, name="class")], axis=1)
df5
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL1784774  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 1       CHEMBL1784771  CC(=O)N[C@@H](CCC(=O)O)C(=O)N1CCC[C@H]1C(=O)N[...
# 2       CHEMBL1784772  CC(=O)N[C@@H](CC(C(=O)O)C(=O)O)C(=O)N1CCC[C@H]...
# 3       CHEMBL1784773  CC(=O)N[C@H](C(=O)N1CCC[C@H]1C(=O)N[C@H](C(=O)...
# 4       CHEMBL1784704  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N[C@@H](C)C(=O)...
# 5       CHEMBL1784770  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 6       CHEMBL1784703  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 7       CHEMBL1784775  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 8       CHEMBL1784776  CC[C@H](C)[C@H](NC(=O)[C@@H]1CCCN1C(=O)[C@H](C...
# 9       CHEMBL1784777  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 10      CHEMBL2369531  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 11      CHEMBL2369532  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 12      CHEMBL1784779  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 13      CHEMBL1784780  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N[C@@H](C)C(=O)...
# 14      CHEMBL1784781  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 15      CHEMBL1784782  CC(=O)N[C@H](Cc1ccccc1)C(=O)N[C@@H](C(=O)N[C@H...
# 16      CHEMBL1784783  C[C@@H](O)[C@H](NC(=O)[C@@H]1CCCN1C(=O)[C@@H](...
# 17      CHEMBL1784784  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
# 18      CHEMBL1784785  CC(=O)N[C@@H](COP(=O)(O)O)C(=O)N1CCC[C@H]1C(=O...
#
#     standard_value         class
# 0           4600.0  intermediate
# 1         250000.0      inactive
# 2          52800.0      inactive
# 3         250000.0      inactive
# 4          15000.0      inactive
# 5          35000.0      inactive
# 6           3200.0  intermediate
# 7          30100.0      inactive
# 8           7100.0  intermediate
# 9          18400.0      inactive
# 10         17700.0      inactive
# 11        171700.0      inactive
# 12         14900.0      inactive
# 13         98400.0      inactive
# 14        250000.0      inactive
# 15        250000.0      inactive
# 16         10800.0      inactive
# 17          1000.0        active
# 18          1600.0  intermediate

# %% [markdown]
# ##Saves dataframe to CSV file

# %%
#create a csv file for the preprocessed data
df5.to_csv("bioactivity_preprocessed_data.csv", index=False)

# %%
#to check the file
! ls -l
# Out:
# total 12
# -rw-r--r-- 1 root root 2244 Jul 14 09:58 bioactivity_data.csv
# -rw-r--r-- 1 root root 2435 Jul 14 09:58 bioactivity_preprocessed_data.csv
# drwxr-xr-x 1 root root 4096 Jul 11 13:22 sample_data

# %%
#copy into the google drive
! cp bioactivity_preprocessed_data.csv "/cancer/gdrive/MyDrive/Colab Notebooks/data"

# %%
#To have a look
! ls "/cancer/gdrive/MyDrive/Colab Notebooks/data"
# Out:
# bioactivity_data.csv  bioactivity_data_csv  bioactivity_preprocessed_data.csv
